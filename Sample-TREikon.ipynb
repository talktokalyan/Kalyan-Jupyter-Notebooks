# %%
import eikon as ek  # the Eikon Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks

ek.set_app_key('0999f7ba5a704212ad4e1f382863870c4615e33e')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
rics = [
    'RELI.NS',  # Reliance Industries Ltd
    'JUBI.NS',  # Jubilant Foodworks Ltd
    '.BSESN',  # BSE Sensex stock index
    '.NIFVIX',  # India VIX volatility index
    'INR=',  # INR/USD exchange rate
    'XAU=',  # Gold price
    'IN10YT=RR',  # 10yr Bund price
]

# %%
### Getting Symbology
symbology_df = ek.get_symbology(rics, from_symbol_type='RIC', to_symbol_type=['ISIN', 'ticker','SEDOL'])
symbology_df
# Out:
#                    ISIN    ticker    SEDOL                    error
# RELI.NS    INE002A01018  RELIANCE      NaN                      NaN
# JUBI.NS    INE797F01012  JUBLFOOD  B3PRM66                      NaN
# .BSESN     XC0009698199    SENSEX      NaN                      NaN
# .NIFVIX             NaN  INDIAVIX      NaN                      NaN
# INR=                NaN       NaN      NaN  No best match available
# XAU=                NaN       NaN      NaN  No best match available
# IN10YT=RR  IN0020200070       NaN  BMFYQG8                      NaN

# %%
### First get the list of valid RICS which have valid ISIN.
isin_list = list(symbology_df.ISIN.values)
isin_list
# Out:
# ['INE002A01018', 'INE797F01012', 'XC0009698199', nan, nan, nan, 'IN0020200070']

# %%
### Getting Timeseries for FX closing price.
data1 = ek.get_timeseries(['INR=', 'THB=','CNY='],  # the RICs
                         fields='CLOSE',  # close field
                         start_date='2020-01-01',  # start date
                         end_date='2020-05-31')  # end date
data1.normalize().iplot()

### Getting Timeseries for EQUITY RICS.
data2 = ek.get_timeseries(rics[:3],  # the RICs
                         fields='CLOSE',  # close field
                         start_date='2020-01-01',  # start date
                         end_date='2020-05-31')  # end date
data2.normalize().iplot()
# Out:
# <div>
#
#
#             <div id="d4d492de-faab-4934-8bfb-731a91c84a35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d4d492de-faab-4934-8bfb-731a91c84a35")) {
#                     Plotly.newPlot(
#                         'd4d492de-faab-4934-8bfb-731a91c84a35',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "INR=", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-09", "2020-03-10",
41600423953366, 73.21807101218867, 67.28272390037097, 66.77265500794914, 64.15606783253843, 60.79093799682036, 67.43177000529943, 58.561870694223636, 62.493375728669854, 71.69117647058825, 70.62798092209857, 70.58823529411765, 68.25980392156863, 73.77782193958666, 71.57193958664547, 71.37321144674087, 79.89533651298359, 78.97125066242714, 80.81279809220987, 78.77252252252254, 76.16918388977211, 77.37480127186011, 81.0810810810811, 82.39268680445151, 81.9654213036566, 90.32856385797562, 90.81213566507685, 93.86592474827769, 94.7105193428723, 94.60453100158983, 94.525039745628, 97.11181770005301, 95.07154213036567, 96.75741918388978, 96.76404345521993, 99.82445680975094, 103.45786963434023, 104.45151033386328, 97.98953365129836, 100.06855202358629, 96.02287899914378, 97.5909952375434, 96.34385801595904, 94.21402849813272, 95.87242008501163, 96.37729333021065, 95.72864823372977, 95.22711851995591, 96.66483703277432, 98.45028281380928, 97.9253483800593]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "JUBI.NS", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-27", "2020-01-28", "2020-01-29", "20 ...

# %%
### GET DATA ON CLOSING DATA & RETURN
price_data, err = ek.get_data(rics, ['TR.PriceClose', 'TR.Volume', 'TR.PriceLow',
                                        'TR.TotalReturnYTD', 'TR.TotalReturn52WK'])
price_data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/eikon/data_grid.py:247: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   Instrument  Price Close      Volume   Price Low  YTD Total Return  \
# 0    RELI.NS    1717.9000  18312705.0   1713.0500  15.2028205029568
# 1    JUBI.NS    1782.9500    801258.0   1737.7000  7.37005879951251
# 2     .BSESN   34842.1000  24559109.0  34499.7800               NaN
# 3    .NIFVIX      29.7275         NaN     29.0575               NaN
# 4       INR=          NaN         NaN         NaN
# 5       XAU=          NaN         NaN         NaN
# 6  IN10YT=RR          NaN         NaN         NaN
#
#   52 Week Total Return
# 0     35.5176024251791
# 1     42.5754574121659
# 2                  NaN
# 3                  NaN
# 4
# 5
# 6

# %%
cols = ['YTD Total Return', '52 Week Total Return']
price_data[:2].set_index('Instrument')[cols].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="429d54fa-5fc0-417b-bb88-1752c8ddf092" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("429d54fa-5fc0-417b-bb88-1752c8ddf092")) {
#                     Plotly.newPlot(
#                         '429d54fa-5fc0-417b-bb88-1752c8ddf092',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "YTD Total Return", "orientation": "v", "text": "", "type": "bar", "x": ["RELI.NS", "JUBI.NS"], "y": ["15.2028205029568", "7.37005879951251"]}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "52 Week Total Return", "orientation": "v", "text": "", "type": "bar", "x": ["RELI.NS", "JUBI.NS"], "y": ["35.5176024251791", "42.5754574121659"]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
#### GET DATA OF INDEX COMPONENTS
sensex_data = ek.get_data('0#.BSESN', fields=['TR.CommonName', 'TR.PriceClose',
                                      'TR.Volume', 'TR.TotalReturnYTD'])[0]
sensex_data
sensex_data.set_index('Company Common Name')['YTD Total Return'].sort_values().iplot(kind='bar', color='green')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/eikon/data_grid.py:247: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="e3f7187f-0b22-48e8-923a-7811af5bc634" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e3f7187f-0b22-48e8-923a-7811af5bc634")) {
#                     Plotly.newPlot(
#                         'e3f7187f-0b22-48e8-923a-7811af5bc634',
#                         [{"marker": {"color": "rgba(0, 128, 0, 0.6)", "line": {"color": "rgba(0, 128, 0, 1.0)", "width": 1}}, "name": "YTD Total Return", "orientation": "v", "text": "", "type": "bar", "x": ["Indusind Bank Ltd", "State Bank of India", "Axis Bank Ltd", "Bajaj Finserv Ltd", "ICICI Bank Ltd", "Tata Steel Ltd", "Bajaj Finance Ltd", "Oil and Natural Gas Corporation Ltd", "Housing Development Finance Corporation Ltd", "Tech Mahindra Ltd", "Larsen & Toubro Ltd", "Maruti Suzuki India Ltd", "Kotak Mahindra Bank Ltd", "ITC Ltd", "HDFC Bank Ltd", "NTPC Ltd", "Titan Company Ltd", "Bajaj Auto Ltd", "UltraTech Cement Ltd", "Tata Consultancy Services Ltd", "Mahindra and Mahindra Ltd", "Power Grid Corporation of India Ltd", "Asian Paints Ltd", "HCL Technologies Ltd", "Infosys Ltd", "Hindustan Unilever Ltd", "Sun Pharmaceutical Industries Ltd", "Nestle India Ltd", "Reliance Industries Ltd", "Bharti Airtel Ltd"], "y": [-68.0954587576352, -44.6808510636989, -43.71352784992129, -35.6304312764437, -35.33178654168879, -30.9216101719479, -30.5320385695352, -30.075662306645498, -25.523627999764, -25.3942209446398, -25.3903410943361, -21.9235258987362, -20.1246660716654, -19.2930780556075, -18.823714419438602, -18.0155527292485, -16.8322667591319, -7.68243406907078, -5.5845904856569195, -4.31368815976825, -3.04826418289824, -2.47827220146273, -1.8758857387540702, -1.24225685640087, -1.05719342287741, 11.522506886465699, 12.8222195008125, 13.376542514879699, 15.169865638615802, 22.3014480027031]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
### GET DATA WITH Parameter Values
price_data2, err = ek.get_data('0#.BSESN',fields=['TR.CommonName','TR.Employees', 
                                            {'TR.TreasuryStockCommon':{'params':{'Scale': 3, 'Curn': 'INR'}}},
                                            {'TR.CommonStock':{'params':{'Scale': 3, 'Curn': 'INR'},'sort_dir':'asc'}}
                                                 ])
price_data2
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/eikon/data_grid.py:247: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#    Instrument                          Company Common Name  \
# 0     BJFS.BO                            Bajaj Finserv Ltd
# 1     TITN.BO                            Titan Company Ltd
# 2     ASPN.BO                             Asian Paints Ltd
# 3     NEST.BO                             Nestle India Ltd
# 4     BJFN.BO                            Bajaj Finance Ltd
# 5     MRTI.BO                      Maruti Suzuki India Ltd
# 6      HLL.BO                       Hindustan Unilever Ltd
# 7      SUN.BO            Sun Pharmaceutical Industries Ltd
# 8     LART.BO                          Larsen & Toubro Ltd
# 9     ULTC.BO                         UltraTech Cement Ltd
# 10    BAJA.BO                               Bajaj Auto Ltd
# 11    HDFC.BO  Housing Development Finance Corporation Ltd
# 12     TCS.BO                Tata Consultancy Services Ltd
# 13    TEML.BO                            Tech Mahindra Ltd
# 14    HDBK.BO                                HDFC Bank Ltd
# 15    MAHM.BO                    Mahindra and Mahindra Ltd
# 16    AXBK.BO                                Axis Bank Ltd
# 17    INBK.BO                            Indusind Bank Ltd
# 18    HCLT.BO                         HCL Technologies Ltd
# 19     SBI.BO                          State Bank of India
# 20    TISC.BO                               Tata Steel Ltd
# 21     ITC.BO                                      ITC Ltd
# 22    ICBK.BO                               ICICI Bank Ltd
# 23    KTKM.BO                      Kotak Mahindra Bank Ltd
# 24    INFY.BO                                  Infosys Ltd
# 25    BRTI.BO                            Bharti Airtel Ltd
# 26    PGRD.BO          Power Grid Corporation of India Ltd
# 27    ONGC.BO          Oil and Natural Gas Corporation Ltd
# 28    RELI.BO                      Reliance Industries Ltd
# 29    NTPC.BO                                     NTPC Ltd
#
#     Full-Time Employees  Treasury Stock - Common  Common Stock
# 0                   NaN                      NaN  7.957000e+05
# 1                   NaN                      NaN  8.878000e+05
# 2                   NaN                      NaN  9.592000e+05
# 3                7649.0                      NaN  9.642000e+05
# 4                   NaN                      NaN  1.199900e+06
# 5                   NaN                      NaN  1.510000e+06
# 6               21000.0                      NaN  2.160000e+06
# 7                   NaN                      NaN  2.399300e+06
# 8                   NaN                      NaN  2.807800e+06
# 9                   NaN                      NaN  2.886300e+06
# 10                  NaN                      NaN  2.893700e+06
# 11                  NaN                      NaN  3.464100e+06
# 12             448464.0                      0.0  3.750000e+06
# 13                  NaN                      NaN  4.359000e+06
# 14             116971.0                      NaN  5.483286e+06
# 15                  NaN                      NaN  5.542800e+06
# 16                  NaN                      NaN  5.643400e+06
# 17                  NaN                      NaN  6.935400e+06
# 18             150423.0                      NaN  7.065331e+06
# 19             249448.0                      NaN  8.924612e+06
# 20              75294.0                      NaN  1.144740e+07
# 21              27279.0                      NaN  1.225860e+07
# 22                  NaN                      NaN  1.294760e+07
# 23                  NaN                      NaN  1.456519e+07
# 24             242371.0                      NaN  2.122000e+07
# 25                  NaN                      NaN  2.727800e+07
# 26                  NaN                      NaN  5.231590e+07
# 27              31065.0                      NaN  6.290154e+07
# 28              26488.0                      NaN  6.339000e+07
# 29              20244.0                      NaN  9.894560e+07
