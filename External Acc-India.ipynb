# %% [markdown]
# ### India International Investment Position (Stock of foreign assets and liabilities)

# %%
# International Investment Position (Stock of foreign assets and liabilities)
# data entered by hand from IIP
# Viz--> Circular Packing with multi-level Hierarchy
# Source: https://github.com/holtzy/The-Python-Graph-Gallery/blob/master/src/notebooks/circular-packing-several-levels-of-hierarchy.ipynb
# Pre-requisite Packages----> circlify
# Hierarchical Data of Popultaion of World->Continent->Country 
# import the circlify library
import circlify
import matplotlib.pyplot as plt

data = [{'id': 'India', 'datum': 2210.3 , 'children' : [
              {'id' : "Assets", 'datum': 926.2,
                   'children' : [
                     {'id' : "Direct Inv", 'datum' : 206.4,
                       'children' : [
                        {'id' : "Equity", 'datum' : 129.3},
                        {'id' : "Debt Sec", 'datum' : 77.1}
                        ]},
                     {'id' : "Portfolio Inv", 'datum' : 9.7,
                       'children' : [
                        {'id' : "Equity", 'datum' : 6.4},
                        {'id' : "Debt Sec", 'datum' : 3.3}
                        ]},
                     {'id' : "Other Inv", 'datum' : 76.5,
                       'children' : [
                        {'id' : "Trade Credit", 'datum' : 12.9},
                        {'id' : "Loans", 'datum' : 8.9},
                        {'id' : "Currency & Deposits", 'datum' : 34.8},
                        {'id' : "Other", 'datum' : 19.9}
                        ]},
                     {'id' : "Reserve Assets", 'datum' : 633.6}
                   ]},
    
                  {'id' : "Liabilities", 'datum': 1214.7,
                   'children' : [
                     {'id' : "Direct Inv", 'datum' : 514.3,
                      'children' : [
                        {'id' : "Equity", 'datum' : 488},
                        {'id' : "Debt Sec", 'datum' : 26.4}
                        ]},
                     {'id' : "Portfolio Inv", 'datum' : 277.2,
                       'children' : [
                        {'id' : "Equity", 'datum' : 172.8},
                        {'id' : "Debt Sec", 'datum' : 104.4}
                        ]},
                     {'id' : "Other Inv", 'datum' : 492.6,
                       'children' : [
                        {'id' : "Trade Credit", 'datum' : 113.5},
                        {'id' : "Loans", 'datum' : 204},
                        {'id' : "Currency & Deposits", 'datum' : 143.5},
                        {'id' : "Other", 'datum' : 31.6}
                        ]}
                  ]}                    
        ]}]

# Compute circle positions thanks to the circlify() function
circles = circlify.circlify(
    data, 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=0, y=0, r=1)
)


# Create just a figure and only one subplot
fig, ax = plt.subplots(figsize=(14,14))

# Title
#ax.set_title('International Investment Position - India (USD Billion)')

# Remove axes
ax.axis('off')

# Find axis boundaries
lim = max(
    max(
        abs(circle.x) + circle.r,
        abs(circle.y) + circle.r,
    )
    for circle in circles
)
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)

# Print circle the highest level (continents):
for circle in circles:
    if circle.level != 2:
      continue
    x, y, r = circle
    ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="green"))

# Print circle and labels for the mezzanine level:
for circle in circles:
    if circle.level != 3:
      continue
    x, y, r = circle
    label = circle.ex["id"] + " \n " +  str(circle.ex["datum"] )
    ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=1.5, color="red"))
    plt.annotate(label, (x,y-0.1 ),va='bottom', ha='center', color="white", bbox=dict(facecolor='olive', edgecolor='black', boxstyle='round', pad=0.25))

# Print circle and labels for the lowest level:
for circle in circles:
    if circle.level != 4:
      continue
    x, y, r = circle
    label = circle.ex["id"] + " \n " +  str(circle.ex["datum"] ) 
    ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=1, color="blue"))
    plt.annotate(label, (x,y),va='bottom',  ha='center', color="white")
    
# Print labels for the continents
for circle in circles:
    if circle.level != 2:
      continue
    x, y, r = circle
    label = circle.ex["id"] + " \n " +  str(circle.ex["datum"] ) 
    plt.annotate(label, (x,y+0.5), va='top', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round', pad=1))

# %% [markdown]
# ### External Debt (Stock Account)
#     1. Debt by Source / Creditor
#     2. Debt by Destination / Debitor / user
#     3. Debt by Instrument

# %%
import pandas as pd
import plotly.express as px

df_ins= pd.read_excel(r'./data/India-External Debt.xlsx', sheet_name='EX-DEBT-INSTRUMENT') 
cols=list(df_ins.columns.values.tolist())
print(df_ins)
fig = px.treemap(
    df_ins, path=[px.Constant("External Debt by Instrument (USD Billion)"),'Instrument','Dec-21 P'],
    values=df_ins['Dec-21 P'],labels=df_ins['Instrument'],
    color_continuous_scale='RdBu'
)
fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
#                                 Instrument  Dec-20 PR  Sep-21 PR  Dec-21 P
# 0     Special Drawing Rights (allocations)        5.7       23.3      23.2
# 1                    Currency and deposits      142.5      142.9     143.5
# 2                          Debt securities       99.6      105.6     104.4
# 3                                    Loans      192.2      201.1     204.0
# 4               Trade credits and advances      102.6      104.4     113.5
# 5                   Other debt liabilities        0.0        0.0       0.0
# 6  Direct investment: Intercompany lending       25.7       26.1      26.4
# <div>                            <div id="6b272af4-fb93-41c1-bb13-6b233b648159" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b272af4-fb93-41c1-bb13-6b233b648159")) {                    Plotly.newPlot(                        "6b272af4-fb93-41c1-bb13-6b233b648159",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Dec-21 P=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["External Debt by Instrument (USD Billion)/Other debt liabilities/0.0","External Debt by Instrument (USD Billion)/Special Drawing Rights (allocations)/23.2","External Debt by Instrument (USD Billion)/Direct investment: Intercompany lending/26.4","External Debt by Instrument (USD Billion)/Debt securities/104.4","External Debt by Instrument (USD Billion)/Trade credits and advances/113.5","External Debt by Instrument (USD Billion)/Currency and deposits/143.5","External Debt by Instrument (USD Billion)/Loans/204.0","External Debt by Instrument (USD Billion)/Currency and deposits","External Debt by Instrument (USD Billion)/Debt securities","External Debt by Instrument (USD Billion)/Direct investment: Intercompany lending","External Debt by Instrument (USD Billion)/Loans","External Debt by Instrument (USD Billion)/Other debt liabilities","External Debt by Instrument (USD Billion)/Special Drawing Rights (allocations)","External Debt by Instrument (USD Billion)/Trade credits and advances","External Debt by Instrument (USD Billion)"],"labels":["0.0","23.2","26.4","104.4","113.5","143.5","204.0","Currency and deposits","Debt securities","Direct investment: Intercompany lending","Loans","Other debt liabilities","Special Drawing Rights (allocations)","Trade credits and advances","External Debt by Instrument (USD Billion)"],"name":"","parents":["External Debt by Instrument (USD Billion)/Other debt liabilities","External Debt by Instrument (USD Billion)/Special Drawing Rights (allocations)","External Debt by Instrument (USD Billion)/Direct investment: Intercompany lending","External Debt by Instrument (USD Billion)/Debt securities","External Debt by Instrument (USD Billion)/Trade credits and advances","External Debt by Instrument (USD Billion)/Currency and deposits","External Debt by Instrument (USD Billion)/Loans","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)","External Debt by Instrument (USD Billion)",""],"values":[0.0,23.2,26.4,104.4,113.5,143.5,204.0,143.5,104.4,26.4,204.0,0.0,23.2,113.5,615.0],"type":"treemap","root":{"color":"lightgrey"}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...
