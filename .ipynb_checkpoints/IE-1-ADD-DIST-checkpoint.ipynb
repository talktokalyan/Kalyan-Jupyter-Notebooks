# %% [markdown]
# # Central Moments & Standardized Moments of key distributions

# %%
import numpy as np
import scipy.stats as spstats
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)

std_norm = spstats.norm(0,1) #  Std normal
std_norm_grid = np.linspace(std_norm.ppf(0.001),std_norm.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)

# Std Normal 
Z_mean, Z_var, Z_skew, Z_kurt = std_norm.stats(moments="mvsk")
print('Mean =', Z_mean, 'Variance =', Z_var, 'Skew =' , Z_skew, 'Kurtosis =', Z_kurt )

fig1, ax1 = plt.subplots(1,1)
ax1.plot(std_norm_grid, std_norm.pdf(std_norm_grid), '--', lw=1, label ='Std. Normal pdf ~ Normal$(\mu=0,\sigma^2=1)$')
ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# Mean = 0.0 Variance = 1.0 Skew = 0.0 Kurtosis = 0.0
# /Users/kalyan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# Normal 
N_norm = spstats.norm(loc=2, scale=3)
N_mean, N_var, N_skew, N_kurt = N_norm.stats(moments="mvsk")
print('Mean =', N_mean, 'Variance =', N_var, 'Skew =' , N_skew, 'Kurtosis =', N_kurt )

N_norm_grid = np.linspace(N_norm.ppf(0.01),N_norm.ppf(0.99), 100) # Prepare the x-axis values as percent point values (percentiles)

fig1, ax1 = plt.subplots(1,1)
ax1.plot(N_norm_grid, N_norm.pdf(N_norm_grid), 'k-', lw=1, label ='Normal pdf ~ N$(\mu={},\sigma^2={})$'. format(N_mean, N_var), color='orange')
ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# Mean = 2.0 Variance = 9.0 Skew = 0.0 Kurtosis = 0.0
# /Users/kalyan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# CHI Square
chi2_dist = spstats.chi2(df=5)
chi2_mean, chi2_var, chi2_skew, chi2_kurt = chi2_dist.stats(moments="mvsk")
print('Mean =', chi2_mean, 'Variance =', chi2_var, 'Skew =' , chi2_skew, 'Kurtosis =', chi2_kurt )
chi2_grid = np.linspace(chi2_dist.ppf(0.01),chi2_dist.ppf(0.99), 100) # Prepare the x-axis values as percent point values (percentiles)

fig1, ax1 = plt.subplots(1,1)
ax1.plot(chi2_grid, chi2_dist.pdf(chi2_grid), 'k-', lw=1, label ='Chi square pdf ~ $\chi^2(\mu={},\sigma^2={})$'. format(chi2_mean, chi2_var), color='green')
ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# Mean = 5.0 Variance = 10.0 Skew = 1.2649110640673518 Kurtosis = 2.4
# /Users/kalyan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# F Dist
F_dist = spstats.f(10,20)
F_mean, F_var, F_skew, F_kurt = F_dist.stats(moments="mvsk")
print('Mean =', F_mean, 'Variance =', F_var, 'Skew =' , F_skew, 'Kurtosis =', F_kurt )
F_grid = np.linspace(F_dist.ppf(0.01),F_dist.ppf(0.99), 100) # Prepare the x-axis values as percent point values (percentiles)

fig1, ax1 = plt.subplots(1,1)
ax1.plot(F_grid, F_dist.pdf(F_grid), 'k-', lw=1, label ='F Dist. pdf ~ $F(\mu={},\sigma^2={})$'. format(F_mean, F_var), color='red')
ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# /Users/kalyan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# Mean = 1.1111111111111112 Variance = 0.43209876543209874 Skew = 1.8351920959819217 Kurtosis = 6.893877551020408

# %%
# Students t Dist
t_dist = spstats.t(20)
t_mean, t_var, t_skew, t_kurt = t_dist.stats(moments="mvsk")
print('Mean =', t_mean, 'Variance =', t_var, 'Skew =' , t_skew, 'Kurtosis =', t_kurt )
t_grid = np.linspace(t_dist.ppf(0.01),t_dist.ppf(0.99), 100) # Prepare the x-axis values as percent point values (percentiles)

fig1, ax1 = plt.subplots(1,1)
ax1.plot(t_grid, t_dist.pdf(t_grid), 'k-', lw=1, label ='t Dist. pdf ~ $t(\mu={},\sigma^2={})$'. format(t_mean, t_var), color='blue')
ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# Mean = 0.0 Variance = 1.1111111111111112 Skew = 0.0 Kurtosis = 0.375
# /Users/kalyan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# Combined picture

fig_comb, ax_comb = plt.subplots(1,1)
ax_comb.plot(t_grid, t_dist.pdf(t_grid), 'k-', lw=1, label ='t Dist' , color='blue')
ax_comb.plot(F_grid, F_dist.pdf(F_grid), 'k-', lw=1, label ='F Dist', color='red')
ax_comb.plot(chi2_grid, chi2_dist.pdf(chi2_grid), 'k-', lw=1, label ='Chi square', color='green')
ax_comb.plot(N_norm_grid, N_norm.pdf(N_norm_grid), 'k-', lw=1, label ='Normal', color='orange')
ax_comb.plot(std_norm_grid, std_norm.pdf(std_norm_grid), '--', lw=1, label ='Std. Normal', color='black')
ax_comb.legend(loc='best', frameon=True)

fig_comb.show()

# %% [markdown]
# # Equivalence of Distributions - Adding Random Values of Distributions
# This notebook demonstrates the following:
# 1. Sum of 'N' I.I.D Standard Normal Variables  == Normal Distribution
#     1. $\forall (Z_1,Z_2...Z_n) $ ~ $N(\mu=0,\sigma^2=1) \implies$ $Y=(Z_1+Z_2+...+Z_n) $ ~ $  N(\mu=0,Var =n\times \sigma^2)$
# 1. Sum of Square of Standard Normal Variables == _Chi-square Distribution_
#     1. $\forall (Z_1,Z_2...Z_n) $ ~ $N(\mu=0,\sigma^2=1) \implies$ $Y=(Z^2_1+Z^2_2+...+Z^2_n) $ ~ $  \chi^2_{df=n}$
# 1. The divison of two independent Chi-squared distrbutions  == _F Distribution_
#    1. If  $ X_1 $ ~ $ \chi^2_{df_1}$ and  $ X_2 = \chi^2_{df_2}  \implies$ $ Y = \frac{(X_1/df_1)}{(X_2/df_2)} $ ~ $ F_{df_1, df_2} $
# 1. The division of a Standard Normal with a square root of Chi-square == _Student's t Distribution_
#     1. If  $ Z $ ~ $ N(\mu=0,\sigma^2=1)$ and $ X $ ~ $ \chi^2_{df_1}$ then $ Y = \frac{Z}{\sqrt(X/df_1)} $ ~ $ t(df_1)$

# %%
import numpy as np
import scipy.stats as spstats
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)

ss = 500 # sample size of each independent distribution
num_iid = 5 # Number of random independent variables

##############  PART 1 #################

##### Demonstrate relation b/w Sum of Normal and Sum of Square of Standard Normal Distribution. #####

std_norm = spstats.norm(0,1) #  Std normal
th_chi2 = spstats.chi2(num_iid) # Theoretical Chi-Square with df = num_iid
th_norm = spstats.norm(0,num_iid**(0.5)) # Theortical Normal with Mean = 0 and Variance = N**(0.5)

i = 0
Y_1 = 0
Y_2 = 0

for i in range(num_iid):
    i = i + 1
   # print("obs{}".format(x))
    obs_i = std_norm.rvs(ss)
    Y_1 = Y_1 + obs_i
    Y_2 = Y_2 + (obs_i)**2

std_norm_grid = np.linspace(std_norm.ppf(0.001),std_norm.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)
th_norm_grid = np.linspace(th_norm.ppf(0.001),th_norm.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)
th_chi2_grid = np.linspace(th_chi2.ppf(0.001),th_chi2.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)

fig, ax = plt.subplots(1,2)

ax[0].hist(Y_1, bins=50, density=True, alpha=0.5, label ='$Y = \sum (Z_i) ; i = (1...{})$'.format(num_iid), color='green', edgecolor='red')
ax[0].plot(th_norm_grid, th_norm.pdf(th_norm_grid), 'k-', lw=1, label ='Theoretical pdf ~ Normal$(\mu=0,Var=n(\sigma^2))$ ; n={}'.format(num_iid))
ax[0].plot(std_norm_grid, std_norm.pdf(std_norm_grid), '--', lw=1, label ='Std. Normal pdf ~ Normal$(\mu=0,\sigma^2=1)$')
ax[0].legend(loc='best', frameon=True)

ax[1].hist(Y_2, bins=50, density=True, label ='$Y = \sum (Z_i)^2 ; i=(1...{})$'.format(num_iid), color='blue', edgecolor='white')
ax[1].plot(th_chi2_grid, th_chi2.pdf(th_chi2_grid), 'k-', lw=1, label ='Theoretical pdf ~ $\chi^2_n $; df=n={}'.format(num_iid))
ax[1].legend(loc='best', frameon=False)

plt.show()
###############################


##############  PART 2 #################
##### Demonstrate relation b/w two Chi2 == F Distribution. #####
df1 = 10
df2 = 20
# Theoretical Distributions for comparison #
th_chi2_1 = spstats.chi2(df1)
th_chi2_2 = spstats.chi2(df2)
th_f = spstats.f(df1,df2)
#####

X_1 = th_chi2_1.rvs(ss)
X_2 = th_chi2_2.rvs(ss)
Y_3 = (X_1/df1) / (X_2/df2)

th_f_grid = np.linspace(th_f.ppf(0.001),th_f.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)

fig2, ax2 = plt.subplots(1,2)
ax2[0].hist(Y_3, bins=50, density=True, alpha=0.5, label ='$ Y = (X_1/k1)/(X_2/k2) $',color='red', edgecolor='blue')
ax2[0].plot(th_f_grid, th_f.pdf(th_f_grid), 'k-', lw=1, label ='Theoretical pdf ~$ F_{k1,k2}$')
ax2[0].legend(loc='best', frameon=False)

##### Demonstrate relation b/w Std. Normal (Z) and Chi-square == Student's t-Distribution. #####
# Theoretical Distributions for comparison #
th_t = spstats.t(df1)
#####

new_Z = std_norm.rvs(ss)
Y_4 = (new_Z) / (X_1/df1)**(0.5)

th_t_grid = np.linspace(th_t.ppf(0.001),th_t.ppf(0.999), 100) # Prepare the x-axis values as percent point values (percentiles)

ax2[1].hist(Y_4, bins=50, density=True, alpha=0.5, label ='$Y = Z/(X/n)**(1/2)$',color='orange', edgecolor='blue')
ax2[1].plot(th_t_grid, th_t.pdf(th_t_grid), 'k-', lw=1, label ='Theoretical pdf ~ $ t_n $; df = n = {}'.format(df1))
ax2[1].plot(std_norm_grid, std_norm.pdf(std_norm_grid), '--', lw=1, label ='Std. Normal pdf ~ Normal$(\mu=0,\sigma^2=1)$')

ax2[1].legend(loc='best', frameon=False)

plt.show()
###############################

# %%
# Skewness

import numpy as np
import scipy.stats as spstats
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)

ss = 500 # sample size of each independent distribution
num_iid = 5 # Number of random independent variables
fig1, ax1 = plt.subplots(1,1)

# Lskew
a, b = 5,2
l_skew = spstats.beta(a, b)
lmean, lvar, lskew, lkurt = l_skew.stats(moments='mvsk')

x = np.linspace(l_skew.ppf(0.01),
                l_skew.ppf(0.99), 100)
ax1.plot(x, l_skew.pdf(x),
       'r-', lw=5, alpha=0.6, label='Left Skew (negative skew) S ={}'.format)

# Rskew
c,d = 2,5
r_skew = spstats.beta(c,d)
rmean, rvar, rskew, rkurt = r_skew.stats(moments='mvsk')

x = np.linspace(r_skew.ppf(0.01),
                r_skew.ppf(0.99), 100)
ax1.plot(x, r_skew.pdf(x),
       'g-', lw=5, alpha=0.6, label='Right Skew (Positive skew) pdf')

ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# <ipython-input-20-db4f30dd0547>:48: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()

# %%
# Kurtosis

import numpy as np
import scipy.stats as spstats
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)

ss = 500 # sample size of each independent distribution
num_iid = 5 # Number of random independent variables
fig1, ax1 = plt.subplots(1,1)

# Lepto
a=5
lepto = spstats.t(a)
lmean, lvar, lskew, lkurt = lepto.stats(moments='mvsk')

x = np.linspace(lepto.ppf(0.001),
                lepto.ppf(0.999), 100)
ax1.plot(x, lepto.pdf(x),
       'r-', lw=1, alpha=0.6, label='Leptokurtic (Skinny peak). K={}'.format(lkurt))

# Platy
c,d=10,20
platy = spstats.t(c)
pmean, pvar, pskew, pkurt = platy.stats(moments='mvsk')

x = np.linspace(platy.ppf(0.001),
                platy.ppf(0.999), 100)
ax1.plot(x, platy.pdf(x),
       'g-', lw=1, alpha=0.6, label='Platykurtic (Broad peak). K={}'.format(pkurt))

#Meso-Std Normal
meso = spstats.norm(0,1)
mmean, mvar, mskew, mkurt = meso.stats(moments='mvsk')

x = np.linspace(meso.ppf(0.001),
                meso.ppf(0.999), 100)
ax1.plot(x, meso.pdf(x),
       'b-', lw=1, alpha=0.6, label='Mesokurtic (Normal Dist peak). K={}'.format(mkurt))

ax1.legend(loc='best', frameon=True)
fig1.show()
# Out:
# <ipython-input-64-930464bd084b>:43: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()
