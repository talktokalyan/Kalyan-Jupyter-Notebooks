# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 

# Folder path containing the XLSX files
folder_path = '/Users/kalyan/Library/CloudStorage/OneDrive-IIMVIZAG/Python-Exercise-KK/Kalyan-Jupyter-Notebooks/Capex/'

filename_1 = "Announced_Cost_2014-22.xlsx"
file_path_1 = os.path.join(folder_path, filename_1)

filename_2 = "Completed_Cost_2014-2022.xlsx"
file_path_2 = os.path.join(folder_path, filename_2)

df1 = pd.read_excel(file_path_1)
df2 =  pd.read_excel(file_path_2)
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-dad714f0243d> in <module>
#      13 file_path_2 = os.path.join(folder_path, filename_2)
#      14
# ---> 15 df1 = pd.read_excel(file_path_1)
#      16 df2 =  pd.read_excel(file_path_2)
#      17 df1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df1.columns =['State', 'Announced 14-15', 'Announced 15-16', 'Announced 16-17','Announced 17-18','Announced 18-19','Announced 19-20','Announced 20-21','Announced 21-22','Announced 22-23']
drop = [36, 37, 38]
valid_rows = [idx for idx in drop if idx < len(df1)]
df1 = df1.drop(df1.index[valid_rows])

df1
# Out:
#                                    State  Announced 14-15  Announced 15-16
# 0                         Andhra Pradesh        5769743.1        6263311.9  \
# 1                      Arunachal Pradesh        2953228.6        1862158.7
# 2                                  Assam         641579.2         423424.3
# 3                                  Bihar        1374811.3        1357349.8
# 4                           Chhattisgarh        1542557.9        1690944.1
# 5                           NCT of Delhi        1093630.0        1295290.8
# 6                                    Goa          77768.9         213372.2
# 7                                Gujarat        6917059.1        5884393.1
# 8                                Haryana        2661708.7        2980930.3
# 9                       Himachal Pradesh         830590.8         877347.0
# 10                             Jharkhand        2515862.2        2537190.1
# ...

# %%
df2.columns =['state', 'Completed 14-15', 'Completed 15-16', 'Completed 16-17','Completed 17-18','Completed 18-19','Completed 19-20','Completed 20-21','Completed 21-22','Completed 22-23']
drop = [36, 37, 38]
valid_rows = [idx for idx in drop if idx < len(df2)]
df2 = df2.drop(df2.index[valid_rows])

df2
# Out:
#                                    state  Completed 14-15  Completed 15-16
# 0                         Andhra Pradesh         265635.5         565132.0  \
# 1                      Arunachal Pradesh              NaN           2688.3
# 2                                  Assam           4805.2         116551.5
# 3                                  Bihar         103575.6         172357.1
# 4                           Chhattisgarh         112109.0         375903.2
# 5                           NCT of Delhi          18654.2          41043.7
# 6                                    Goa           4977.4           2377.0
# 7                                Gujarat         297255.6         325846.5
# 8                                Haryana         228617.6          33420.9
# 9                       Himachal Pradesh          79618.5          77892.7
# 10                             Jharkhand         236934.3          79828.0
# ...

# %%
df = pd.concat([df1, df2], axis=1, join='inner')
df=df.drop('state', axis=1)
df
# Out:
#                                    State  Announced 14-15  Announced 15-16
# 0                         Andhra Pradesh        5769743.1        6263311.9  \
# 1                      Arunachal Pradesh        2953228.6        1862158.7
# 2                                  Assam         641579.2         423424.3
# 3                                  Bihar        1374811.3        1357349.8
# 4                           Chhattisgarh        1542557.9        1690944.1
# 5                           NCT of Delhi        1093630.0        1295290.8
# 6                                    Goa          77768.9         213372.2
# 7                                Gujarat        6917059.1        5884393.1
# 8                                Haryana        2661708.7        2980930.3
# 9                       Himachal Pradesh         830590.8         877347.0
# 10                             Jharkhand        2515862.2        2537190.1
# ...

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Completed 16-17    6
# Completed 19-20    5
# Completed 14-15    4
# Completed 18-19    4
# Completed 20-21    3
# Completed 17-18    3
# Completed 15-16    3
# Completed 22-23    2
# Completed 21-22    2
# State              0
# Announced 14-15    0
# Announced 21-22    0
# Announced 20-21    0
# Announced 19-20    0
# Announced 18-19    0
# Announced 17-18    0
# Announced 16-17    0
# Announced 15-16    0
# Announced 22-23    0
# dtype: int64

# %%
df['Completed 16-17'] = df['Completed 16-17'].fillna(df['Completed 16-17'].dropna().mean())
df['Completed 19-20'] = df['Completed 19-20'].fillna(df['Completed 19-20'].dropna().mean())
df['Completed 14-15'] = df['Completed 14-15'].fillna(df['Completed 14-15'].dropna().mean())
df['Completed 18-19'] = df['Completed 18-19'].fillna(df['Completed 18-19'].dropna().mean())
df['Completed 20-21'] = df['Completed 20-21'].fillna(df['Completed 20-21'].dropna().mean())
df['Completed 21-22'] = df['Completed 21-22'].fillna(df['Completed 21-22'].dropna().mean())
df['Completed 22-23'] = df['Completed 22-23'].fillna(df['Completed 22-23'].dropna().mean())
df['Completed 17-18'] = df['Completed 17-18'].fillna(df['Completed 17-18'].dropna().mean())
df['Completed 15-16'] = df['Completed 15-16'].fillna(df['Completed 15-16'].dropna().mean())
df.isnull().sum().sort_values(ascending = False)
# Out:
# State              0
# Completed 14-15    0
# Completed 21-22    0
# Completed 20-21    0
# Completed 19-20    0
# Completed 18-19    0
# Completed 17-18    0
# Completed 16-17    0
# Completed 15-16    0
# Announced 22-23    0
# Announced 14-15    0
# Announced 21-22    0
# Announced 20-21    0
# Announced 19-20    0
# Announced 18-19    0
# Announced 17-18    0
# Announced 16-17    0
# Announced 15-16    0
# Completed 22-23    0
# dtype: int64

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
km = KMeans(n_clusters=5)
x  = df.drop("State", axis='columns')
y_predict = km.fit_predict(x)
y_predict
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([3, 2, 0, 0, 2, 0, 0, 3, 2, 0, 2, 0, 1, 2, 2, 4, 0, 0, 0, 0, 3, 0,
#        2, 0, 1, 2, 0, 2, 0, 2, 0, 0, 0, 0, 0, 0])

# %%
df['cluster'] = y_predict
df.head()
# Out:
#                State  Announced 14-15  Announced 15-16  Announced 16-17
# 0     Andhra Pradesh        5769743.1        6263311.9        6185588.5  \
# 1  Arunachal Pradesh        2953228.6        1862158.7        1923114.0
# 2              Assam         641579.2         423424.3         903055.4
# 3              Bihar        1374811.3        1357349.8        1370227.0
# 4       Chhattisgarh        1542557.9        1690944.1        1090042.3
#
#    Announced 17-18  Announced 18-19  Announced 19-20  Announced 20-21
# 0        5817653.3        5694277.6        7215428.0        4823946.1  \
# 1        1155806.2        1111934.3        1134206.2         981495.2
# 2        1174420.9        1042662.4        1083368.0         332802.2
# 3        1182621.3         712217.2         561696.0         384374.5
# 4        1069841.0        1102243.4        1116532.0        1136075.9
#
#    Announced 21-22  Announced 22-23  Completed 14-15  Completed 15-16
# ...

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]
df4 = df[df.cluster == 3]
df5 = df[df.cluster == 4]
plt.figure(figsize=(8,10))
plt.scatter(df1['Announced 14-15'],df1['State'], color ='green')
plt.scatter(df2['Announced 14-15'],df2['State'], color ='red')
plt.scatter(df3['Announced 14-15'],df3['State'], color ='blue')
plt.scatter(df4['Announced 14-15'],df4['State'], color ='brown')
plt.scatter(df5['Announced 14-15'],df5['State'], color ='orange')

# %%
scaler = MinMaxScaler()
scaler.fit(df[['Announced 14-15', 'Announced 15-16', 'Announced 16-17','Announced 17-18','Announced 18-19','Announced 19-20','Announced 20-21','Announced 21-22','Announced 22-23','Completed 14-15', 'Completed 15-16', 'Completed 16-17','Completed 17-18','Completed 18-19','Completed 19-20','Completed 20-21','Completed 21-22','Completed 22-23']])
df[['Announced 14-15', 'Announced 15-16', 'Announced 16-17','Announced 17-18','Announced 18-19','Announced 19-20','Announced 20-21','Announced 21-22','Announced 22-23','Completed 14-15', 'Completed 15-16', 'Completed 16-17','Completed 17-18','Completed 18-19','Completed 19-20','Completed 20-21','Completed 21-22','Completed 22-23']] = scaler.transform(df[['Announced 14-15', 'Announced 15-16', 'Announced 16-17','Announced 17-18','Announced 18-19','Announced 19-20','Announced 20-21','Announced 21-22','Announced 22-23','Completed 14-15', 'Completed 15-16', 'Completed 16-17','Completed 17-18','Completed 18-19','Completed 19-20','Completed 20-21','Completed 21-22','Completed 22-23']])
df
# Out:
#                                    State  Announced 14-15  Announced 15-16
# 0                         Andhra Pradesh         0.834052         0.798423  \
# 1                      Arunachal Pradesh         0.426672         0.236944
# 2                                  Assam         0.092315         0.053397
# 3                                  Bihar         0.198370         0.172543
# 4                           Chhattisgarh         0.222633         0.215102
# 5                           NCT of Delhi         0.157700         0.164626
# 6                                    Goa         0.010766         0.026600
# 7                                Gujarat         1.000000         0.750083
# 8                                Haryana         0.384507         0.379672
# 9                       Himachal Pradesh         0.119654         0.111307
# 10                             Jharkhand         0.363411         0.323062
# ...

# %%
x  = df.drop("State", axis='columns')
x = x.drop("cluster", axis='columns')
y_predict = km.fit_predict(x)
y_predict
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([4, 1, 1, 1, 1, 1, 3, 2, 0, 3, 1, 3, 0, 1, 0, 2, 3, 3, 3, 3, 4, 1,
#        0, 3, 4, 1, 3, 0, 3, 1, 1, 3, 3, 1, 1, 3])

# %%
df['cluster'] = y_predict
df.head()
# Out:
#                State  Announced 14-15  Announced 15-16  Announced 16-17
# 0     Andhra Pradesh         0.834052         0.798423         0.713168  \
# 1  Arunachal Pradesh         0.426672         0.236944         0.221325
# 2              Assam         0.092315         0.053397         0.103621
# 3              Bihar         0.198370         0.172543         0.157528
# 4       Chhattisgarh         0.222633         0.215102         0.125198
#
#    Announced 17-18  Announced 18-19  Announced 19-20  Announced 20-21
# 0         0.626942         0.863230         1.000000         0.790744  \
# 1         0.123533         0.167263         0.156189         0.158267
# 2         0.125543         0.156742         0.149135         0.051490
# 3         0.126429         0.106554         0.076749         0.059979
# 4         0.114250         0.165791         0.153736         0.183711
#
#    Announced 21-22  Announced 22-23  Completed 14-15  Completed 15-16
# ...

# %%
k_rng = range(1,10)
ssl = []
for k in k_rng:
    km = KMeans(n_clusters =k)
    km.fit(x)
    ssl.append(km.inertia_)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
ssl
# Out:
# [41.83466716341859,
#  16.709973597107194,
#  11.43978772574711,
#  9.572075367253962,
#  8.337880991325344,
#  7.120266486044245,
#  6.261802781605133,
#  5.407150479779204,
#  4.828573465374776]

# %%
plt.plot(k_rng,ssl)

# %%
y = df[['State', 'cluster']]
y
# Out:
#                                    State  cluster
# 0                         Andhra Pradesh        4
# 1                      Arunachal Pradesh        1
# 2                                  Assam        1
# 3                                  Bihar        1
# 4                           Chhattisgarh        1
# 5                           NCT of Delhi        1
# 6                                    Goa        3
# 7                                Gujarat        2
# 8                                Haryana        0
# 9                       Himachal Pradesh        3
# 10                             Jharkhand        1
# 11                       Jammu & Kashmir        3
# 12                             Karnataka        0
# 13                                Kerala        1
# 14                        Madhya Pradesh        0
# 15                           Maharashtra        2
# 16                               Manipur        3
# 17                             Meghalaya        3
# ...
