# %% [markdown]
# # Create Lok Sabha Election Panel (1999 to 2024)

# %%
# Project folder
poll_proj_folder = "/Users/kalyan/Library/CloudStorage/OneDrive-Personal/Kalyan/KK-Python/Kalyan-Jupyter-Notebooks/"
ls_poll_raw_folder = "data/Trivedi Centre for Political Data/1.raw/"
ls_poll_interim_folder = "data/Trivedi Centre for Political Data/2.interim/"
ls_poll_cleaned_folder = "data/Trivedi Centre for Political Data/3.cleaned/"

# Files Names
pc_ac_wise_1999_2019_file = "PC-Election-Data-AC-Wise-1999-2019.xlsx"
pc_ac_wise_2024_file = "PC-Election-Data-AC-Wise-2024.xlsx"

print('Folder and File Names set-up')
# Out:
# Folder and File Names set-up

# %%
import os
import pandas as pd

pc_poll_file_path_1 = os.path.join(poll_proj_folder, ls_poll_interim_folder, pc_ac_wise_1999_2019_file)
pc_poll_file_path_2 = os.path.join(poll_proj_folder, ls_poll_interim_folder, pc_ac_wise_2024_file)

df_1 = pd.read_excel(pc_poll_file_path_1 , sheet_name='data' )
print(df_1.columns)
df_2 = pd.read_excel(pc_poll_file_path_2 , sheet_name='data' )
print(df_2.columns)

df_appended = pd.concat([df_1, df_2], ignore_index=True)
print(df_appended)

a = df_appended['Year'].value_counts()
b = df_appended['Year'].unique()

print([b,a])
# Out:
# Index(['Assembly_No', 'State_Name', 'Constituency_No', 'Poll_No', 'Year',
#        'PC_Name', 'PC_No', 'Constituency_Name', 'Constituency_Type', 'CandID',
#        'Candidate', 'Party', 'Votes', 'Position', 'N_Cand', 'Valid_Votes',
#        'Vote_Share_Percentage', 'Deposit_Lost', 'Margin', 'Margin_Percentage',
#        'ENOP', 'Sex', 'pid', 'Candidate_Type', 'DelimID', 'Party_ID',
#        'Party_Type_TCPD', 'Contested', 'Last_Party', 'Last_Party_ID',
#        'Last_Constituency_Name', 'Same_Constituency', 'Same_Party', 'No_Terms',
#        'Turncoat', 'Incumbent', 'Recontest', 'MyNeta_education',
#        'TCPD_Prof_Main', 'TCPD_Prof_Main_Desc', 'TCPD_Prof_Second',
#        'TCPD_Prof_Second_Desc', 'Election_Type'],
#       dtype='object')
# Index(['State_Name', 'PC_No', 'PC_Name', 'TOTAL ELECTORS IN PC',
#        'Constituency_No', 'Constituency_Name', 'TOTAL ELECTORS IN AC',
#        'TOTAL VALID VOTES IN STATE', 'NOTA VOTES EVM IN AC', 'Candidate',
# ...
