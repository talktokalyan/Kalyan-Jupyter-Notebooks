# %% [markdown]
# ### Donut Chart

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df=pd.DataFrame({'x':['Market A', 'Market B', 'Market C'],
 'y':[45, 35, 20]})
df
plt.figure(figsize=(10, 10)) # change the size of a figure
# The slices will be ordered and plotted counter-clockwise.
labels = df['x']
sizes = df['y']
colors = ['#FFB600', '#09A0DA','#8464a0'] #define colors of three donut pieces
explode = (0, 0, 0) # explode a slice if required
textprops = {'fontsize':14,'color':'black'} # Font size of text in donut chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
 autopct='%.2f%%', # Show data in 0.00%
 pctdistance =0.9,
 shadow=False,
 frame=True,
 textprops =textprops,
 wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},)
 
#draw a circle at the center of pie to make it look like a donut
centre_circle = plt.Circle((0,0),0.65,color='grey', fc='grey',linewidth=1.00)
fig = plt.gcf() # get
fig.gca().add_artist(centre_circle)
plt.axis('equal') # Set aspect ratio to be equal so that pie is      drawn as a circle.
plt.show()

# %% [markdown]
# ### Nested Donut Chart

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df=pd.DataFrame({'x':['Market A', 'Market B', 'Market C'],
 'y':[45, 35, 20]})
df

plt.figure(figsize=(8, 8)) # change the size of a figure
labels = df['x']
sizes = df['y']
colors = ['#FFB600', '#09A0DA','#8464a0']
labels_subgroup = ['product A', 'product B', 'product C', 'product D', 'product E', 'product F', 'product G']
sizes_subgroup = [20, 15, 10, 20, 15, 10, 10]
colors_subgroup = ['#FFCE53', '#FFDA7E', '#FFE9B2', '#30B7EA',
 '#56C7F2', '#C8A2C9','#D6A7DF']
 
outside_donut = plt.pie(sizes, labels=labels, colors=colors,
 startangle=90, frame=True,
 autopct='%.2f%%',
 pctdistance =0.85,
 )
inside_donut = plt.pie(sizes_subgroup, labels=labels_subgroup,
 colors=colors_subgroup, radius=0.7,
 startangle=90, labeldistance=0.6,
 autopct='%.2f%%',
 pctdistance =0.4)
centre_circle = plt.Circle((0, 0), 0.4, color='white', linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
 
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Plotly
import plotly.graph_objects as go
import pandas as pd

labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.show()

trace1 = {
  "hole": 0.8, 
  "type": "pie", 
  "labels": ["AMC", "Cadillac", "Camaro", "Chrysler", "Datsun", "Dodge", "Duster", "Ferrari", "Fiat", "Ford", "Honda", "Hornet", "Lincoln", "Lotus", "Maserati", "Mazda", "Merc", "Pontiac", "Porsche", "Toyota", "Valiant", "Volvo"], 
  "values": [1, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 2, 7, 1, 1, 2, 1, 1], 
  "showlegend": False
}
trace2 = {
  "name": 4, 
  "type": "bar", 
  "x": [4], 
  "y": [26.6636363636364]
}
trace3 = {
  "name": 6, 
  "type": "bar", 
  "x": [6], 
  "y": [19.7428571428571]
}
trace4 = {
  "name": 8, 
  "type": "bar", 
  "x": [8], 
  "y": [15.1]
}
data = pd.DataFrame([trace1, trace2, trace3, trace4])
layout = {
  "title": "Donut charts using Plotly", 
  "xaxis": {
    "title": "Cylinder", 
    "domain": [0.33, 0.67]
  }, 
  "yaxis": {
    "title": "Avg MPG", 
    "domain": [0.33, 0.67]
  }
}
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="12a180e1-1b9f-49f8-99f7-c7f4c17534af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12a180e1-1b9f-49f8-99f7-c7f4c17534af")) {                    Plotly.newPlot(                        "12a180e1-1b9f-49f8-99f7-c7f4c17534af",                        [{"hole":0.3,"labels":["Oxygen","Hydrogen","Carbon_Dioxide","Nitrogen"],"type":"pie","values":[4500,2500,1053,500]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":
# ...

# %%
import plotly.graph_objects as go

fig =go.Figure(go.Sunburst(
    labels=["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"],
    parents=["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve" ],
    values=[10, 14, 12, 10, 2, 6, 6, 4, 4],
))
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.show()
# Out:
# <div>                            <div id="75478d5a-e7da-473e-bbe0-b4bb10e047a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75478d5a-e7da-473e-bbe0-b4bb10e047a3")) {                    Plotly.newPlot(                        "75478d5a-e7da-473e-bbe0-b4bb10e047a3",                        [{"labels":["Eve","Cain","Seth","Enos","Noam","Abel","Awan","Enoch","Azura"],"parents":["","Eve","Eve","Seth","Seth","Eve","Eve","Awan","Eve"],"type":"sunburst","values":[10,14,12,10,2,6,6,4,4]}],                        {"margin":{"b":0,"l":0,"r":0,"t":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_excel('/Users/kalyan/Library/CloudStorage/OneDrive-IIMVIZAG/Kalyan-Research/APO/Data-Analysis-Manuscript/Employment-by-Industry-India.xlsx'
                  , sheet_name='Employment-Quarterly', usecols="A:C,E:J", header=3, index_col = 0 )


parents = ['', 'Agriculture', 'Industry', 'Industry','Industry','Industry', 'Services', 'Others']
labels = df.columns.to_list()


# df_emp = pd.DataFrame(dict(
#     parents = parents,
#     labels = labels,
#     values= [398963487,141067371,629703,33982164,1303666,70708664,151199795,72124],
#     ))

# print(df_emp)

# fig =go.Figure(go.Sunburst(
#     labels = df_emp['labels'],
#     parents = df_emp['parents'],
#     values = df_emp['values'],
# ))

data = dict(
    parents = parents,
    labels = labels,
#     values= [398963487,141067371,629703,33982164,1303666,70708664,151199795,72124],
        values= [100,50,25,10,11,5,6,1],

    )

fig =px.sunburst( 
    data, 
    names='labels',
    parents='parents',
    values='values',
)

fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.show()
# Out:
# <div>                            <div id="a30fd20f-b63b-4228-936f-0a6dd540a582" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a30fd20f-b63b-4228-936f-0a6dd540a582")) {                    Plotly.newPlot(                        "a30fd20f-b63b-4228-936f-0a6dd540a582",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>value=%{value}<br>parent=%{parent}<extra></extra>","labels":["Total ","Agriculture ","Mining ","Manufacturing ","Utilities ","Real estate &  construction ","Services ","Not classified  elsewhere "],"name":"","parents":["","Agriculture","Industry","Industry","Industry","Industry","Services","Others"],"type":"sunburst","values":[100,50,25,10,11,5,6,1]}],                        {"legend":{"t
# ...

# %%
import plotly.express as px
df = px.data.tips()
print(df)
fig = px.sunburst(df, path=['day', 'time', 'sex'], values='total_bill')
fig.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...

# %%
import plotly.express as px
df = pd.read_excel('/Users/kalyan/Library/CloudStorage/OneDrive-IIMVIZAG/Kalyan-Research/APO/Data-Analysis-Manuscript/Employment-by-Industry-India.xlsx'
                  , sheet_name='Sheet1', )
print(df)
fig = px.sunburst(df, path=['parent1', 'parent2','child'], values='Sep-22')
fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(title ="India - Employment by Sector/Industry",margin = dict(t=40, l=0, r=0, b=0))
fig.show()
# Out:
#   parent1                     parent2                         child  \
# 0  Total                 Agriculture                   Agriculture
# 1  Total                    Industry                        Mining
# 2  Total                    Industry                 Manufacturing
# 3  Total                    Industry                     Utilities
# 4  Total                    Industry   Real estate &  construction
# 5  Total                    Services                      Services
# 6  Total   Not classified  elsewhere     Not classified  elsewhere
#
#       Sep-22  GVA
# 0  141067371  NaN
# 1     629703  NaN
# 2   33982164  NaN
# 3    1303666  NaN
# 4   70708664  NaN
# 5  151199795  NaN
# 6      72124  NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-519af87828e1> in <module>
#       4 print(df)
# ...
